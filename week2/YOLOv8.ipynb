# %% [markdown]
# <a href="https://colab.research.google.com/github/ShanmathiVasudevan/Siamese_NN_WiDS_SV/blob/main/week2/YOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install the ultralytics package from PyPI
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 903.1/903.1 kB 15.1 MB/s eta 0:00:00
# ...

# %%
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 6.25M/6.25M [00:00<00:00, 163MB/s]
# Ultralytics 8.3.54 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 134k/134k [00:00<00:00, 14.6MB/s]
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 328.9ms
# Speed: 16.6ms preprocess, 328.9ms inference, 35.1ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO
from IPython.display import display,Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Out:
# /content/drive/.shortcut-targets-by-id/1rPFkpiEhn5CKgT7EPZRF9sOCepsvL-hM/car

# %%
# !yolo task=detect mode=train model=yolo11n.pt data='/content/drive/MyDrive/Colab Notebooks/car/data.yaml' epochs=10 imgsz=640 plots=True
# Out:
# Ultralytics 8.3.54 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train2/weights/best.pt data='/content/drive/MyDrive/Colab Notebooks/car/data.yaml'
# Out:
# Ultralytics 8.3.54 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 238 layers, 2,585,272 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /content/drive/MyDrive/Colab Notebooks/car/valid/labels.cache... 160 images, 1 backgrounds, 0 corrupt: 100% 160/160 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 10/10 [00:57<00:00,  5.79s/it]
#                    all        160       1055      0.726      0.746      0.739      0.528
#                   boot         35         39      0.704      0.718      0.647      0.448
#                    car        142        145      0.915      0.972      0.965       0.86
#                   door         50         52      0.905      0.919      0.952      0.683
#           front_bumper         30         30      0.545      0.533       0.55      0.421
#            front_grill         49         51      0.667      0.706      0.642      0.498
# ...

# %%
Image(filename='/content/runs/detect/train2/confusion_matrix.png',width=600)

# %%
Image(filename='/content/runs/detect/train2/results.png',width=600)

# %%
# !yolo task=detect mode=predict model='/content/runs/detect/train2/weights/best.pt' conf=0.5 source='/content/drive/MyDrive/Colab Notebooks/car/test/images'
# Out:
# Ultralytics 8.3.54 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 238 layers, 2,585,272 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/22 /content/drive/MyDrive/Colab Notebooks/car/test/images/Cars212_png.rf.c31b66dbfb5e4d5bc2e10f4b331f03aa.jpg: 640x640 1 license_plate, 241.8ms
# image 2/22 /content/drive/MyDrive/Colab Notebooks/car/test/images/Cars260_png.rf.358fc27422dbe6062fced88e7e5b59cc.jpg: 640x640 2 cars, 1 license_plate, 236.3ms
# image 3/22 /content/drive/MyDrive/Colab Notebooks/car/test/images/Cars295_png.rf.5452c67121f3be7c3e37148a9cc4936d.jpg: 640x640 3 cars, 2 license_plates, 357.5ms
# image 4/22 /content/drive/MyDrive/Colab Notebooks/car/test/images/Cars304_png.rf.f31408152fe09e73a74c2949a65058a0.jpg: 640x640 1 front_grill, 1 license_plate, 348.1ms
# ...
